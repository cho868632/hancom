# %%
from ultralytics import YOLO
import cv2

# %%
stream_url = "https://strm1.spatic.go.kr/live/36.stream/chunklist_w626582203.m3u8"
cap = cv2.VideoCapture(stream_url)

# %%
model = YOLO("yolo26s.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26s.pt to 'yolo26s.pt': 100% ━━━━━━━━━━━━ 19.5MB 56.5MB/s 0.3s0.3s<0.0s

# %%
# 3. 프레임 처리
while cap.isOpened():
    success, frame = cap.read()
    if not success:
        print("프레임 읽기 실패 . . .")
        break

    # 객체 추적 수행
    results = model.track(frame, persist=True, conf=0.6)
    # persist=True => 이전 프레임 정보 유지

    # 추적 결과 시각화
    annotated_frame = results[0].plot()

    # 결과 화면 조절
    cv2.namedWindow("YOLO_TRACKING", cv2.WINDOW_NORMAL)
    cv2.imshow("YOLO_TRACKING", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("q키를 눌러서 종료")
        break
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Using Python 3.9.25 environment at: C:\Users\Har29\anaconda3\envs\hancom
# Resolved 2 packages in 603ms
# Prepared 1 package in 83ms
# Installed 1 package in 11ms
#  + lap==0.5.13
#
# requirements: AutoUpdate success  1.1s
# WARNING requirements: Restart runtime or rerun command for updates to take effect
#
#
# 0: 384x640 4 cars, 1 bus, 190.9ms
# Speed: 10.5ms preprocess, 190.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 127.2ms
# Speed: 3.2ms preprocess, 127.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 119.2ms
# Speed: 5.4ms preprocess, 119.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 121.8ms
# Speed: 2.2ms preprocess, 121.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 146.3ms
# Speed: 1.9ms preprocess, 146.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 120.0ms
# Speed: 2.5ms preprocess, 120.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 119.5ms
# Speed: 3.4ms preprocess, 119.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 143.0ms
# Speed: 2.7ms preprocess, 143.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 136.4ms
# Speed: 3.8ms preprocess, 136.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 128.3ms
# Speed: 2.9ms preprocess, 128.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 126.1ms
# Speed: 2.3ms preprocess, 126.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 132.9ms
# Speed: 3.7ms preprocess, 132.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 131.5ms
# Speed: 2.1ms preprocess, 131.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 132.9ms
# Speed: 2.1ms preprocess, 132.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 131.0ms
# Speed: 3.8ms preprocess, 131.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 126.0ms
# Speed: 1.9ms preprocess, 126.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 136.2ms
# Speed: 2.6ms preprocess, 136.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 201.7ms
# Speed: 2.6ms preprocess, 201.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 118.7ms
# Speed: 3.2ms preprocess, 118.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 108.3ms
# Speed: 1.9ms preprocess, 108.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 113.4ms
# Speed: 1.7ms preprocess, 113.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 114.5ms
# Speed: 2.3ms preprocess, 114.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 114.4ms
# Speed: 1.9ms preprocess, 114.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 118.7ms
# Speed: 1.9ms preprocess, 118.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 125.9ms
# Speed: 2.4ms preprocess, 125.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 141.5ms
# Speed: 2.4ms preprocess, 141.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 136.4ms
# Speed: 2.4ms preprocess, 136.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 150.3ms
# Speed: 2.4ms preprocess, 150.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 131.1ms
# Speed: 2.7ms preprocess, 131.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 133.5ms
# Speed: 3.2ms preprocess, 133.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# q키를 눌러서 종료

# %%
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cap.release()
#       2 cv2.destroyAllWindows()
#
# NameError: name 'cap' is not defined

# %%
cap.release()
cv2.destroyAllWindows()
